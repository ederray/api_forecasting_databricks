# %%
# carregamento de bibliotecas
import sys
import os
import requests
from bs4 import BeautifulSoup
from datetime import date, timedelta
import pandas as pd
from pyspark.sql import functions as F
from pyspark.sql import DataFrame

# %%
# VARIÁVEIS DE DESTINO
TABELA_INCREMENTAL_RAW = "`api-forecasting`.bronze.precos_gasolina_incremental_raw"

# %%
 dbutils.library.restartPython()

# %%
path = "/mnt/data/Etanol - Centro de Estudos Avançados em Economia Aplicada - CEPEA-Esalq_USP.html"

with open(path, "r", encoding="utf-8") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")


table = soup.find("table", {"id": "imagenet-indicador3"})


first_row = table.tbody.find("tr")

cols = [td.get_text(strip=True) for td in first_row.find_all("td")]

cols
